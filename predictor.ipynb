# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/data_temp.csv')

# %%
# data['DOW3_FIR_MID'] = data['DOW_3'] * data['FIR_MID_WEK']
# data['NOT3_FIR_MID'] = data['NOT_WED'] * data['FIR_MID_WEK']
# data['DOW3_LST'] = data['DOW_3'] * data['LST_WEK']
# data['NOT3_LST'] = data['NOT_WED'] * data['LST_WEK']
# data['OPR*V7'] = data['OPR-NUM'] / data['V7']
# data['WEK_NOT_LST'] = data['WEK_1'] + data['WEK_2'] + data['WEK_3'] + data['WEK_4']
# data['WEK_LST'] = data['WEK_5']
# data['WEK_NOT_LST_RTE'] = data['WEK_1_RTE'] + data['WEK_2_RTE'] + data['WEK_3_RTE'] + data['WEK_4_RTE']
# data['WEK_LST_RTE'] = data['WEK_5_RTE']
# data['DOW_3&5'] = data['DOW_3'] + data['DOW_5']
# data['DOW_NOT3&5'] = data['DOW_1'] + data['DOW_2'] + data['DOW_4'] + data['DOW_6'] + data['DOW_7']
# data['before_dawn'] = data['HOUR_0'] + data['HOUR_1'] + data['HOUR_2'] + data['HOUR_3'] + data['HOUR_4'] + data['HOUR_5']
# data['morning'] = data['HOUR_6'] + data['HOUR_7'] + data['HOUR_8'] + data['HOUR_9'] + data['HOUR_10']
# data['noon'] = data['HOUR_11'] + data['HOUR_12'] + data['HOUR_13']
# data['afternoon'] = data['HOUR_14'] + data['HOUR_15'] + data['HOUR_16']
# data['before_night'] = data['HOUR_17'] + data['HOUR_18'] + data['HOUR_19'] + data['HOUR_20']
# data['night'] = data['HOUR_21'] + data['HOUR_22'] + data['HOUR_23']

# %%
data = data.drop([
    # V中共线性的
    'V10', 
    'V12', 
    'V20',
#     'V30',
#     'OPR-NUM',
#     'OPR-NUM-MAX',
#     'OPR-NUM-MIN',
#     'OPR-NUM-MEA',
#     'OPR-NUM-STD',
    'H5_NUM',
    'H5_FRQ',
#     'WEK_1',
#     'WEK_1_RTE',
#     'WEK_2',
#     'WEK_2_RTE',
#     'WEK_3',
#     'WEK_3_RTE',
#     'WEK_4',
#     'WEK_4_RTE',
#     'WEK_5',
#     'WEK_5_RTE',
    'TIC_CLS_0',
    'TIC_CLS_10',
    'TIC_CLS_102',
    'TIC_CLS_139',
    'TIC_CLS_162',
    'TIC_CLS_163',
    'TIC_CLS_181',
    'TIC_CLS_257',
    'TIC_CLS_259',
    'TIC_CLS_326',
    'TIC_CLS_359',
#     'TIC_CLS_372',
    'TIC_CLS_38',
    'TIC_CLS_396',
    'TIC_CLS_438',
#     'TIC_CLS_460',
#     'TIC_CLS_508',
#     'TIC_CLS_518',
#     'TIC_CLS_520',
    'TIC_CLS_540',
#     'TIC_CLS_604',
#     'next_time_mean',
#     'next_time_std',
#     'next_time_max',
#     'next_time_min',
#     'DOW_1',
#     'DOW_2',
#     'DOW_3',
#     'DOW_4',
#     'DOW_5',
#     'DOW_6',
#     'DOW_7',
    'evt1_max',
    'evt1_min',
    'evt1_mean',
    'evt1_std',
    'DOW1_RAT',
    'DOW2_RAT',
    'DOW3_RAT',
    'DOW4_RAT',
    'DOW5_RAT',
    'DOW6_RAT',
    'DOW7_RAT',
#     'TIC_CLS_0_RAT',
#     'TIC_CLS_10_RAT',
#     'TIC_CLS_102_RAT',
#     'TIC_CLS_139_RAT',
#     'TIC_CLS_162_RAT',
#     'TIC_CLS_163_RAT',
#     'TIC_CLS_181_RAT',
#     'TIC_CLS_257_RAT',
#     'TIC_CLS_259_RAT',
#     'TIC_CLS_326_RAT',
#     'TIC_CLS_359_RAT',
    'TIC_CLS_372_RAT',
#     'TIC_CLS_38_RAT',
#     'TIC_CLS_396_RAT',
#     'TIC_CLS_438_RAT',
    'TIC_CLS_460_RAT',
    'TIC_CLS_508_RAT',
    'TIC_CLS_518_RAT',
    'TIC_CLS_520_RAT',
#     'TIC_CLS_540_RAT',
    'TIC_CLS_604_RAT',
    'SAM_TIC_MAX',
    'SAM_TIC_MIN',
    'SAM_TIC_MEA',
    'SAM_TIC_STD',
    'TIC_CLS_OTR_RAT',
    'NOT_WED',
    'NOT_WED_RAT',
    'V3&V7',
    'V4&V29',
    'V4&V7',
    'V4&V13',
    'HOUR_0',
    'HOUR_1',
    'HOUR_10',
    'HOUR_11',
    'HOUR_12',
    'HOUR_13',
    'HOUR_14',
    'HOUR_15',
    'HOUR_16',
    'HOUR_17',
    'HOUR_18',
    'HOUR_19',
    'HOUR_2',
    'HOUR_20',
    'HOUR_21',
    'HOUR_22',
    'HOUR_23',
    'HOUR_3',
    'HOUR_4',
    'HOUR_5',
    'HOUR_6',
    'HOUR_7',
    'HOUR_8',
    'HOUR_9',
    'HOUR_0_RAT',
    'HOUR_1_RAT',
    'HOUR_10_RAT',
    'HOUR_11_RAT',
    'HOUR_12_RAT',
    'HOUR_13_RAT',
    'HOUR_14_RAT',
    'HOUR_15_RAT',
    'HOUR_16_RAT',
    'HOUR_17_RAT',
    'HOUR_18_RAT',
    'HOUR_19_RAT',
    'HOUR_2_RAT',
    'HOUR_20_RAT',
    'HOUR_21_RAT',
    'HOUR_22_RAT',
    'HOUR_23_RAT',
    'HOUR_3_RAT',
    'HOUR_4_RAT',
    'HOUR_5_RAT',
    'HOUR_6_RAT',
    'HOUR_7_RAT',
    'HOUR_8_RAT',
    'HOUR_9_RAT',
], axis=1)

# %%
list(data.columns)
# Out:
# ['V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V11',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'V29',
#  'V30',
#  'USRID',
#  'FLAG',
#  'OPR-NUM',
#  'OPR-NUM-MAX',
#  'OPR-NUM-MIN',
#  'OPR-NUM-MEA',
#  'OPR-NUM-STD',
#  'WEK_1',
#  'WEK_1_RTE',
#  'WEK_2',
#  'WEK_2_RTE',
#  'WEK_3',
#  'WEK_3_RTE',
#  'WEK_4',
#  'WEK_4_RTE',
#  'WEK_5',
#  'WEK_5_RTE',
#  'TIC_CLS_372',
#  'TIC_CLS_460',
#  'TIC_CLS_508',
#  'TIC_CLS_518',
#  'TIC_CLS_520',
#  'TIC_CLS_604',
#  'next_time_mean',
#  'next_time_std',
#  'next_time_max',
#  'next_time_min',
#  'DOW_1',
#  'DOW_2',
#  'DOW_3',
#  'DOW_4',
#  'DOW_5',
#  'DOW_6',
#  'DOW_7',
#  'TIC_CLS_0_RAT',
#  'TIC_CLS_10_RAT',
#  'TIC_CLS_102_RAT',
#  'TIC_CLS_139_RAT',
#  'TIC_CLS_162_RAT',
#  'TIC_CLS_163_RAT',
#  'TIC_CLS_181_RAT',
#  'TIC_CLS_257_RAT',
#  'TIC_CLS_259_RAT',
#  'TIC_CLS_326_RAT',
# ...

# %%
corr_matrix = data.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %%
[col for col in upper.columns if any(upper[col] > 0.9)]
# Out:
# ['OPR-NUM-STD', 'TIC_CLS_520']

# %%
data_drop = [col for col in upper.columns if any(upper[col] > 0.9)]
# data = data.drop(data_drop, axis=1)

# %%
# upper[data_drop]

# %%
from sklearn.model_selection import StratifiedKFold

train = data[data['FLAG'] != -1]
test = data[data['FLAG'] == -1]

train_userid = train.pop('USRID')
train_userid
y = train.pop('FLAG')

col = train.columns
X = train[col].values

test_userid = test.pop('USRID')
test_y = test.pop('FLAG')
test = test[col].values

N = 5
skf = StratifiedKFold(n_splits=N, shuffle=False, random_state=224)

# %%
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

xx_cv = []
xx_pre = []

for train_in, test_in in skf.split(X, y):
    X_train, X_test, y_train, y_test = X[train_in], X[test_in], y[train_in], y[test_in]
    
    # create dataset for lightgbm
    lgb_train = lgb.Dataset(X_train, y_train, feature_name=list(col))
    lgb_eval = lgb.Dataset(X_test, y_test, feature_name=list(col), reference=lgb_train)
    
    # specify your configurations as a dict
    params = {
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': {'auc'},
        'num_leaves': 32,
        'learning_rate': 0.01,
        'feature_fraction': 0.9,
        'bagging_fraction': 0.8,
        'bagging_freq': 5,
        'verbose': 0
    }
    
    print('Starting training...')
    
    # train
    gbm = lgb.train(params,
                   lgb_train,
                   num_boost_round=40000,
                   valid_sets=lgb_eval,
                   verbose_eval=250,
                   early_stopping_rounds=50)
    
    # print('Save model...')
    # save model to file
    # gbm.save_model(model.txt)
    
    print('Start predicting...')
    y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
    xx_cv.append(roc_auc_score(y_test, y_pred))
    xx_pre.append(gbm.predict(test, num_iteration=gbm.best_iteration))
# Out:
# Starting training...
# Training until validation scores don't improve for 50 rounds.
# [250]	valid_0's auc: 0.844507
# [500]	valid_0's auc: 0.853221
# Early stopping, best iteration is:
# [542]	valid_0's auc: 0.85349
# Start predicting...
# Starting training...
# Training until validation scores don't improve for 50 rounds.
# [250]	valid_0's auc: 0.848856
# Early stopping, best iteration is:
# [419]	valid_0's auc: 0.855635
# Start predicting...
# Starting training...
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [60]	valid_0's auc: 0.836914
# Start predicting...
# Starting training...
# Training until validation scores don't improve for 50 rounds.
# [250]	valid_0's auc: 0.845288
# [500]	valid_0's auc: 0.857711
# Early stopping, best iteration is:
# [626]	valid_0's auc: 0.859159
# Start predicting...
# Starting training...
# Training until validation scores don't improve for 50 rounds.
# [250]	valid_0's auc: 0.845016
# ...

# %%
import matplotlib.pylab as plt
import pylab
pylab.rcParams['figure.figsize'] = (20, 15)
lgb.plot_importance(gbm, max_num_features=200)
plt.title("Feature importances")
plt.show()

# %%
xx_pre
# Out:
# [array([0.01131225, 0.01197963, 0.02464318, ..., 0.00765004, 0.01510118,
#         0.23387849]),
#  array([0.01707541, 0.01669553, 0.03287739, ..., 0.01290405, 0.02114767,
#         0.17827045]),
#  array([0.27736333, 0.27736333, 0.28788422, ..., 0.27736333, 0.27736333,
#         0.36205937]),
#  array([0.01223394, 0.01485242, 0.02325545, ..., 0.00621524, 0.01180484,
#         0.13288912]),
#  array([0.0189021 , 0.01931198, 0.03317577, ..., 0.0120566 , 0.02227169,
#         0.18664613])]

# %%
s = 0
for i in xx_pre:
    s = s + i
    
s = s / N
s = [round(x, 4) for x in s]

# %%
res = pd.DataFrame()
res['USRID'] = list(test_userid.values)
res['RST'] = list(s)
print('xx_cv', np.mean(xx_cv))
time_date = time.strftime('%Y-%m-%d', time.localtime(time.time()))
res.to_csv('./submit/%s_%s.csv'%(str(time_date), str(np.mean(xx_cv)).split('.')[1]), sep='\t', index=0)
# Out:
# xx_cv 0.8510807004150467

# %%
 dict(zip(gbm.feature_name(), list(gbm.feature_importance()))), len(list(gbm.feature_importance()))
# Out:
# ({'DOW_1': 83,
#   'DOW_2': 129,
#   'DOW_3': 121,
#   'DOW_4': 83,
#   'DOW_5': 162,
#   'DOW_6': 99,
#   'DOW_7': 80,
#   'OPR-NUM': 516,
#   'OPR-NUM-MAX': 131,
#   'OPR-NUM-MEA': 153,
#   'OPR-NUM-MIN': 89,
#   'OPR-NUM-STD': 104,
#   'TIC_CLS_0_RAT': 201,
#   'TIC_CLS_102_RAT': 57,
#   'TIC_CLS_10_RAT': 107,
#   'TIC_CLS_139_RAT': 191,
#   'TIC_CLS_162_RAT': 38,
#   'TIC_CLS_163_RAT': 180,
#   'TIC_CLS_181_RAT': 104,
#   'TIC_CLS_257_RAT': 175,
#   'TIC_CLS_259_RAT': 140,
#   'TIC_CLS_326_RAT': 476,
#   'TIC_CLS_359_RAT': 458,
#   'TIC_CLS_372': 231,
#   'TIC_CLS_38_RAT': 233,
#   'TIC_CLS_396_RAT': 349,
#   'TIC_CLS_438_RAT': 153,
#   'TIC_CLS_460': 233,
#   'TIC_CLS_508': 288,
#   'TIC_CLS_518': 591,
#   'TIC_CLS_520': 256,
#   'TIC_CLS_540_RAT': 37,
#   'TIC_CLS_604': 311,
#   'V1': 422,
#   'V11': 227,
#   'V13': 200,
#   'V14': 53,
#   'V15': 230,
#   'V16': 39,
#   'V17': 112,
#   'V18': 179,
#   'V19': 214,
#   'V2': 40,
#   'V21': 86,
#   'V22': 44,
#   'V23': 41,
# ...
