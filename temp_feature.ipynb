# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('./data/data_new.csv')

# %%
list(data.columns), len(list(data.columns))
# Out:
# (['V1',
#   'V2',
#   'V3',
#   'V4',
#   'V5',
#   'V6',
#   'V7',
#   'V8',
#   'V9',
#   'V10',
#   'V11',
#   'V12',
#   'V13',
#   'V14',
#   'V15',
#   'V16',
#   'V17',
#   'V18',
#   'V19',
#   'V20',
#   'V21',
#   'V22',
#   'V23',
#   'V24',
#   'V25',
#   'V26',
#   'V27',
#   'V28',
#   'V29',
#   'V30',
#   'USRID',
#   'FLAG',
#   'OPR-NUM',
#   'OPR-NUM-MAX',
#   'OPR-NUM-MIN',
#   'OPR-NUM-MEA',
#   'OPR-NUM-STD',
#   'H5_NUM',
#   'H5_FRQ',
#   'WEK_1',
#   'WEK_1_RTE',
#   'WEK_2',
#   'WEK_2_RTE',
#   'WEK_3',
#   'WEK_3_RTE',
#   'WEK_4',
#   'WEK_4_RTE',
#   'WEK_5',
#   'WEK_5_RTE',
#   'TIC_CLS_0',
#   'TIC_CLS_10',
#   'TIC_CLS_102',
#   'TIC_CLS_139',
#   'TIC_CLS_162',
#   'TIC_CLS_163',
#   'TIC_CLS_181',
#   'TIC_CLS_257',
#   'TIC_CLS_259',
#   'TIC_CLS_326',
#   'TIC_CLS_359',
#   'TIC_CLS_372',
#   'TIC_CLS_38',
#   'TIC_CLS_396',
#   'TIC_CLS_438',
#   'TIC_CLS_460',
#   'TIC_CLS_508',
#   'TIC_CLS_518',
#   'TIC_CLS_520',
#   'TIC_CLS_540',
# ...

# %%
# data['FIR_MID_WEK'] = data['MID_WEK'] + data['FIR_WEK']
# data['FIR_MID_RAT'] = data['MID_RAT'] + data['FIR_RAT']

# %%
data['TIC_CLS_OTR_RAT'] = data['TIC_CLS_102_RAT'] + data['TIC_CLS_10_RAT'] + data['TIC_CLS_162_RAT'] + data['TIC_CLS_540_RAT']

# %%
# data['WED_FRI_SAT'] = data['DOW_3'] + data['DOW_5'] + data['DOW_6']
# data['TUE_THU_SUN'] = data['DOW_2'] + data['DOW_4'] + data['DOW_7']
# data['WED_FRI_SAT_RAT'] = data['DOW3_RAT'] + data['DOW5_RAT'] + data['DOW6_RAT']
# data['TUE_THU_SUN_RAT'] = data['DOW2_RAT'] + data['DOW4_RAT'] + data['DOW7_RAT']

# %%
data['NOT_WED'] = data['DOW_1'] + data['DOW_2'] + data['DOW_4'] + data['DOW_5'] + data['DOW_6'] + data['DOW_7']
data['NOT_WED_RAT'] = data['DOW1_RAT'] + data['DOW2_RAT'] + data['DOW5_RAT'] + data['DOW4_RAT'] + data['DOW6_RAT'] + data['DOW7_RAT']

# %%
V7list = [
    'V3'
]
# V1list = [
#     'V3'
# ]
# V1list = [col for col in data.columns if 'V' in col]

# %%
Vlist = [col for col in data.columns if 'V' in col and '&' not in col]
Vlist
# Out:
# ['V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'V29',
#  'V30']

# %%
V3list = ['V7']
for v in V3list:
    temp = 'V3&' + v
    data[temp] = data['V3'] * data[v]

# %%
V4list = [
    'V29',
    'V7',
    'V13'
]
for v in V4list:
    temp = 'V4&' + v
    data[temp] = data['V4'] * data[v]

# %%
list(data.columns)
# Out:
# ['V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'V29',
#  'V30',
#  'USRID',
#  'FLAG',
#  'OPR-NUM',
#  'OPR-NUM-MAX',
#  'OPR-NUM-MIN',
#  'OPR-NUM-MEA',
#  'OPR-NUM-STD',
#  'H5_NUM',
#  'H5_FRQ',
#  'WEK_1',
#  'WEK_1_RTE',
#  'WEK_2',
#  'WEK_2_RTE',
#  'WEK_3',
#  'WEK_3_RTE',
#  'WEK_4',
#  'WEK_4_RTE',
#  'WEK_5',
#  'WEK_5_RTE',
#  'TIC_CLS_0',
#  'TIC_CLS_10',
#  'TIC_CLS_102',
#  'TIC_CLS_139',
#  'TIC_CLS_162',
#  'TIC_CLS_163',
#  'TIC_CLS_181',
#  'TIC_CLS_257',
#  'TIC_CLS_259',
#  'TIC_CLS_326',
#  'TIC_CLS_359',
#  'TIC_CLS_372',
#  'TIC_CLS_38',
#  'TIC_CLS_396',
#  'TIC_CLS_438',
#  'TIC_CLS_460',
#  'TIC_CLS_508',
#  'TIC_CLS_518',
#  'TIC_CLS_520',
#  'TIC_CLS_540',
#  'TIC_CLS_604',
#  'HOUR_0',
#  'HOUR_1',
#  'HOUR_10',
#  'HOUR_11',
# ...

# %%
data.to_csv('./data/data_temp.csv', index=0)
